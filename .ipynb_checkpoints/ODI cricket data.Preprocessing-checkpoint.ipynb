# %% [markdown]
# Author : Arivazhagan.B
#
# Topic : Pandas Practice
#
# email : arivazhagan45678@gmail.com

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv(r'C:\Users\ELCOT\Desktop\csv file\ODI Cricket Data new.csv')
df
# Out:
#            player_name    role  total_runs            strike_rate  \
# 0              V Kohli  Batter       13784  9.170.381.212.161.530
# 1        KC Sangakkara  Batter       11618  7.939.046.057.127.230
# 2            RG Sharma  Batter       10646  9.035.817.348.497.700
# 3             MS Dhoni  Batter       10274  8.497.932.175.351.530
# 4       AB de Villiers  Batter        9435  9.944.139.966.273.180
# ...                ...     ...         ...                    ...
# 1535        C Sakariya  Batter           0                      0
# 1536  Shahriar Hossain  Batter           0                      0
# 1537      Salman Faris  Batter           0                      0
# 1538  Haseebullah Khan  Batter           0                      0
# 1539  Syeda Aroob Shah  Batter           0                      0
#
#      total_balls_faced  total_wickets_taken  total_runs_conceded  \
# 0                15031                    7                  681
# ...

# %%
df.isnull().sum()
# Out:
# player_name                 0
# role                        0
# total_runs                  0
# strike_rate                 0
# total_balls_faced           0
# total_wickets_taken         0
# total_runs_conceded         0
# total_overs_bowled          0
# total_matches_played        0
# matches_played_as_batter    0
# matches_played_as_bowler    0
# matches_won                 0
# matches_lost                0
# player_of_match_awards      0
# team                        0
# average                     0
# percentage                  0
# dtype: int64

# %%
year=np.random.uniform(low=2016,high=2024,size=len(df['player_name']))
year=np.around(year,decimals=0)
year
# Out:
# array([2022., 2016., 2022., ..., 2024., 2021., 2024.])

# %%
df['year']=year
df
# Out:
#            player_name    role  total_runs            strike_rate  \
# 0              V Kohli  Batter       13784  9.170.381.212.161.530
# 1        KC Sangakkara  Batter       11618  7.939.046.057.127.230
# 2            RG Sharma  Batter       10646  9.035.817.348.497.700
# 3             MS Dhoni  Batter       10274  8.497.932.175.351.530
# 4       AB de Villiers  Batter        9435  9.944.139.966.273.180
# ...                ...     ...         ...                    ...
# 1535        C Sakariya  Batter           0                      0
# 1536  Shahriar Hossain  Batter           0                      0
# 1537      Salman Faris  Batter           0                      0
# 1538  Haseebullah Khan  Batter           0                      0
# 1539  Syeda Aroob Shah  Batter           0                      0
#
#      total_balls_faced  total_wickets_taken  total_runs_conceded  \
# 0                15031                    7                  681
# ...

# %%
df[df['player_name']=='V Kohli'][['total_runs','total_balls_faced','year']]
# Out:
#    total_runs total_balls_faced    year
# 0       13784             15031  2022.0

# %%
df['team'].nunique()
# Out:
# 25

# %%
df['player_name'].nunique()
# Out:
# 1540

# %%
tl=df[['team','player_name','total_runs','matches_won']]
tl
# Out:
#                       team       player_name  total_runs  matches_won
# 0                    India           V Kohli       13784          360
# 1                Sri Lanka     KC Sangakkara       11618          237
# 2                    India         RG Sharma       10646          358
# 3                    India          MS Dhoni       10274          356
# 4             South Africa    AB de Villiers        9435          286
# ...                    ...               ...         ...          ...
# 1535                 India        C Sakariya           0           41
# 1536            Bangladesh  Shahriar Hossain           0           11
# 1537  United Arab Emirates      Salman Faris           0            3
# 1538              Pakistan  Haseebullah Khan           0            6
# 1539              Pakistan  Syeda Aroob Shah           0            4
#
# [1540 rows x 4 columns]

# %%
df

# %%
df.iloc[0]
# Out:
# player_name                               V Kohli
# role                                       Batter
# total_runs                                  13784
# strike_rate                 9.170.381.212.161.530
# total_balls_faced                           15031
# total_wickets_taken                             7
# total_runs_conceded                           681
# total_overs_bowled                            671
# total_matches_played                          579
# matches_played_as_batter                      579
# matches_played_as_bowler                        0
# matches_won                                   360
# matches_lost                                  219
# player_of_match_awards                         41
# team                                        India
# average                     1.969.142.857.142.850
# percentage                                477,93%
# Name: 0, dtype: object

# %%
Allteam=df.groupby('team')['total_runs'].mean()
count=Allteam[Allteam>=800]
count
sns.barplot(count,palette='rainbow')
# Out:
# C:\Users\ELCOT\AppData\Local\Temp\ipykernel_21808\2364649940.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(count,palette='rainbow')
# <Axes: xlabel='team', ylabel='total_runs'>

# %%
df.head()
# Out:
#       player_name    role  total_runs            strike_rate  \
# 0         V Kohli  Batter       13784  9.170.381.212.161.530
# 1   KC Sangakkara  Batter       11618  7.939.046.057.127.230
# 2       RG Sharma  Batter       10646  9.035.817.348.497.700
# 3        MS Dhoni  Batter       10274  8.497.932.175.351.530
# 4  AB de Villiers  Batter        9435  9.944.139.966.273.180
#
#   total_balls_faced  total_wickets_taken  total_runs_conceded  \
# 0             15031                    7                  681
# 1             14634                    0                    0
# 2             11782                   11                  538
# 3             12090                    1                   32
# 4              9488                    7                  205
#
#    total_overs_bowled  total_matches_played  matches_played_as_batter  \
# 0                 671                   579                       579
# 1                   0                   510                       510
# ...

# %%
df.tail()
# Out:
#            player_name    role  total_runs strike_rate total_balls_faced  \
# 1535        C Sakariya  Batter           0           0                 1
# 1536  Shahriar Hossain  Batter           0           0                 3
# 1537      Salman Faris  Batter           0           0                 2
# 1538  Haseebullah Khan  Batter           0           0                 2
# 1539  Syeda Aroob Shah  Batter           0           0                 1
#
#       total_wickets_taken  total_runs_conceded  total_overs_bowled  \
# 1535                    2                   34                  51
# 1536                    0                    0                   0
# 1537                    0                    0                   0
# 1538                    0                    0                   0
# 1539                    0                    0                   0
#
#       total_matches_played  matches_played_as_batter  \
# 1535                    75                        75
# ...

# %%
df[df[]]
# Out:
# player_name                   0
# role                          0
# total_runs                  0.0
# strike_rate                   0
# total_balls_faced             0
# total_wickets_taken         0.0
# total_runs_conceded         0.0
# total_overs_bowled          0.0
# total_matches_played        0.0
# matches_played_as_batter    0.0
# matches_played_as_bowler    0.0
# matches_won                 0.0
# matches_lost                0.0
# player_of_match_awards      0.0
# team                          0
# average                       0
# percentage                    0
# dtype: object

# %%
India=df[df['team']=='India'].head()
India
# Out:
#      player_name    role  total_runs            strike_rate total_balls_faced  \
# 0        V Kohli  Batter       13784  9.170.381.212.161.530             15031
# 2      RG Sharma  Batter       10646  9.035.817.348.497.700             11782
# 3       MS Dhoni  Batter       10274  8.497.932.175.351.530             12090
# 15  Yuvraj Singh  Batter        6868  8.545.477.168.097.540              8037
# 16      S Dhawan  Batter        6733    894.869.750.132.908              7524
#
#     total_wickets_taken  total_runs_conceded  total_overs_bowled  \
# 0                     7                  681                 671
# 2                    11                  538                 614
# 3                     1                   32                  38
# 15                   99                 3438                4028
# 16                    0                    0                   0
#
#     total_matches_played  matches_played_as_batter  matches_played_as_bowler  \
# ...

# %%
sns.barplot(x='player_name',y='total_runs',data=India,palette='rainbow')
# Out:
# C:\Users\ELCOT\AppData\Local\Temp\ipykernel_4672\1366077875.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='player_name',y='total_runs',data=India,palette='rainbow')
# <Axes: xlabel='player_name', ylabel='total_runs'>

# %%
win=df[['team','matches_won']].head()
win
# Out:
#            team  matches_won
# 0         India          360
# 1     Sri Lanka          237
# 2         India          358
# 3         India          356
# 4  South Africa          286

# %%
sns.barplot(x='team',y='match_won',data=win)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 sns.barplot(x='team',y='match_won',data=win)
#
# NameError: name 'sns' is not defined

# %%
df
